# %%
import gpflow as gpf
import numpy as np 
import scipy
import matplotlib.pyplot as plt
from cpgp.segcpgp import SegCPGP as NormalSegCPGP
from cpgp.segcpgp_sparse import SegCPGP as FastSegCPGP
from cpgp.segcpgp_robust import SegCPGP as RobustSegCPGP
import json
import time
# Out:
# 2025-05-20 13:25:42.109874: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-20 13:25:42.114835: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-20 13:25:42.173921: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-20 13:25:42.174010: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-20 13:25:42.176724: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-20 13:25:42.189429: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-20 13:25:42.190409: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-20 13:25:43.447384: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def plot_result(X, y, segcpgp, ci):
    plt.figure(figsize=(24, 3))
    plt.plot(X, y)
    plt.scatter(ci, np.zeros_like(ci), marker="^", color="r")
    for loc in segcpgp.LOCS:
        plt.axvline(loc, color="r")
        
    with open("/home/janneke/changepoint-gp/TCPD/annotations.json") as f:
        annot = json.load(f)
    for annotation in annot["well_log"]: 
        print(annot["well_log"], sorted(segcpgp.LOCS))
    plt.show()

# %%
def plot_model(model: gpf.models.GPModel) -> None:
    X, Y = model.data
    opt = gpf.optimizers.Scipy()
    opt.minimize(model.training_loss, model.trainable_variables)
    gpf.utilities.print_summary(model, "notebook")

    Xplot = np.linspace(0.0, 200, 200)[:, None]

    y_mean, y_var = model.predict_y(Xplot, full_cov=False)
    y_lower = y_mean - 1.96 * np.sqrt(y_var)
    y_upper = y_mean + 1.96 * np.sqrt(y_var)

    _, ax = plt.subplots(nrows=1, ncols=1)
    ax.plot(X, Y, "kx", mew=2)
    (mean_line,) = ax.plot(Xplot, y_mean, "-")
    color = mean_line.get_color()
    ax.plot(Xplot, y_lower, lw=0.1, color=color)
    ax.plot(Xplot, y_upper, lw=0.1, color=color)
    ax.fill_between(
        Xplot[:, 0], y_lower[:, 0], y_upper[:, 0], color=color, alpha=0.1
    )

    # Also plot the inducing variables if possible:
    iv = getattr(model, "inducing_variable", None)
    if iv is not None:
        ax.scatter(iv.Z, np.zeros_like(iv.Z), marker="^")

# %%
X = np.linspace(0, 1000, 1000).reshape(-1, 1).astype(float)
#y = np.sin(0.05*X)**2
y = np.random.normal(0, 1.5, size=len(X)).reshape(-1, 1)
ci = np.array((250, 750))

y[ci[0]:ci[1]] += 10


plt.plot(X, y)

# %%
segcpgp = FastSegCPGP(n_ind=50)
dt = time.time()
segcpgp.fit(X, y, "noise")
print(time.time() - dt)
plot_result(X, y, segcpgp, ci)
# Out:
# 0.0 1000.0
# p 1.0 df 3 location [430.99234819] steepness [0.97756489]
# 6.358018398284912
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} []
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} []
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} []
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} []
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} []

# %%
segcpgp = NormalSegCPGP()
dt = time.time()
segcpgp.fit(X, y, "constant")
print(time.time() - dt)
plot_result(X, y, segcpgp, ci)
# Out:
# 0.0 1000.0
# 5.528866557908738e-81 3
# p 5.528866557908738e-81 df 3 bic tf.Tensor(177.17821019842052, shape=(), dtype=float64) location [750.71827634] steepness [846.64527818]
# 0.0 744.7447447447448
# 0.0 3
# p 0.0 df 3 bic tf.Tensor(859.4233235790238, shape=(), dtype=float64) location [249.86333202] steepness [5.62409496]
# 0.0 243.24324324324326
# 1.0 3
# p 1.0 df 3 bic tf.Tensor(-8.245752340246735, shape=(), dtype=float64) location [213.83463169] steepness [0.0782044]
# 254.25425425425428 744.7447447447448
# 1.0 3
# p 1.0 df 3 bic tf.Tensor(-9.294666199568686, shape=(), dtype=float64) location [232.19463918] steepness [1.62053677e-41]
# 755.7557557557558 1000.0
# 0.9939089806109243 3
# p 0.9939089806109243 df 3 bic tf.Tensor(-8.21089953572157, shape=(), dtype=float64) location [806.32218688] steepness [24.27476211]
# 96.4184262752533
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} [array([249.86333202]), array([750.71827634])]
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} [array([249.86333202]), array([750.71827634])]
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} [array([249.86333202]), array([750.71827634])]
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} [array([249.86333202]), array([750.71827634])]
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} [array([249.86333202]), array([750.71827634])]

# %%
segcpgp = RobustSegCPGP()
dt = time.time()
segcpgp.fit(X, y, "constant")
print(time.time() - dt)
plot_result(X, y, segcpgp, ci)
# Out:
# 0.0 1000.0
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:1546, in Operation.get_attr(self, name)
#    1545 with c_api_util.tf_buffer() as buf:   # pytype: disable=wrong-arg-count
# -> 1546   pywrap_tf_session.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    1547   data = pywrap_tf_session.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'gradients/Reshape_14_grad/Reshape' has no attr named '_read_only_resource_inputs'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/framework/auto_control_deps_utils.py:105, in get_read_write_resource_inputs(op)
#     104 try:
# --> 105   read_only_input_indices = op.get_attr(READ_ONLY_RESOURCE_INPUTS_ATTR)
#     106 except ValueError:
#     107   # Attr was not set. Add all resource inputs to `writes` and return.
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:1550, in Operation.get_attr(self, name)
#    1548 except errors.InvalidArgumentError as e:
#    1549   # Convert to ValueError for backwards compatibility.
# -> 1550   raise ValueError(e.message)
#    1551 x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'gradients/Reshape_14_grad/Reshape' has no attr named '_read_only_resource_inputs'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 segcpgp = RobustSegCPGP()
#       2 dt = time.time()
# ----> 3 segcpgp.fit(X, y, "constant")
#       4 print(time.time() - dt)
#       5 plot_result(X, y, segcpgp, ci)
#
# File ~/robust-cpgp/cpgp/segcpgp_robust.py:85, in SegCPGP.fit(self, X, y, base_kernel_name, custom_kernel)
#      72 def fit(self, X, y, base_kernel_name="constant", custom_kernel=None):
#      73     """Fit SegCPGP
#      74
#      75     Arguments:
#    (...)
#      83         _description_
#      84     """
# ---> 85     results = self.call(X, y, base_kernel_name, custom_kernel)
#      86     return results
#
# File ~/robust-cpgp/cpgp/segcpgp_robust.py:158, in SegCPGP.call(self, X, y, base_kernel_name, custom_kernel)
#     156 models = {}
#     157 for model_name in ["cp", "gpr"]:
# --> 158     model = self.get_high_likelihood_model(
#     159         X, y, model_name, base_kernel_name, custom_kernel, 5)
#     161     if self.sampling:
#     162         print("+"*100)
#
# File ~/robust-cpgp/cpgp/segcpgp_robust.py:134, in SegCPGP.get_high_likelihood_model(self, X, y, model_name, base_kernel_name, custom_kernel, n_attempts, fit_noise)
#     131         adam_opt.minimize(loss_fn, adam_vars)
#     133     for i in range(100):
# --> 134         optimisation_step()
#     136     models.append(model)
#     138 # Find model with highest likelihood.
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:888, in Function._call(self, *args, **kwds)
#     885 try:
#     886   # This is the first call of __call__, so we have to initialize.
#     887   initializers = []
# --> 888   self._initialize(args, kwds, add_initializers_to=initializers)
#     889 finally:
#     890   # At this point we know that the initialization is complete (or less
#     891   # interestingly an exception was raised) so we no longer need a lock.
#     892   self._lock.release()
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:695, in Function._initialize(self, args, kwds, add_initializers_to)
#     690 self._variable_creation_config = self._generate_scoped_tracing_options(
#     691     variable_capturing_scope,
#     692     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     693 )
#     694 # Force the definition of the function for these arguments
# --> 695 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     696     args, kwds, self._variable_creation_config
#     697 )
#     699 def invalid_creator_scope(*unused_args, **unused_kwds):
#     700   """Disables variable creation."""
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:598, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     594 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     595   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     596   # the function a weak reference to itself to avoid a reference cycle.
#     597   with OptionalXlaContext(compile_with_xla):
# --> 598     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     599   return out
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_filegx_64fkl.py:13, in outer_factory.<locals>.inner_factory.<locals>.tf__optimisation_step()
#      11 def tf__optimisation_step():
#      12     with ag__.FunctionScope('optimisation_step', 'fscope', ag__.ConversionOptions(recursive=True, user_requested=True, optional_features=(), internal_convert_user_code=True)) as fscope:
# ---> 13         ag__.converted_call(ag__.ld(natgrad_opt).minimize, (ag__.ld(loss_fn), ag__.ld(variational_vars)), None, fscope)
#      14         ag__.converted_call(ag__.ld(adam_opt).minimize, (ag__.ld(loss_fn), ag__.ld(adam_vars)), None, fscope)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:441, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     439     result = converted_f(*effective_args, **kwargs)
#     440   else:
# --> 441     result = converted_f(*effective_args)
#     442 except Exception as e:
#     443   _attach_error_metadata(e, converted_f)
#
# File /tmp/__autograph_generated_filem09ei055.py:13, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_method(self, *args, **kwargs)
#      11 try:
#      12     do_return = True
# ---> 13     retval_ = ag__.converted_call(ag__.ld(wrapped_function), (ag__.ld(self),) + tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      14 except:
#      15     do_return = False
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_filejhfkcdu9.py:40, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function(*args, **kwargs)
#      38     nonlocal retval_, do_return
#      39     pass
# ---> 40 ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.ld(get_enable_check_shapes), (), None, fscope)), if_body, else_body, get_state, set_state, ('do_return', 'retval_'), 2)
#      42 def get_state_8():
#      43     return (arg_map, ag__.ldu(lambda: arg_map[RESULT_TOKEN], 'arg_map[RESULT_TOKEN]'), checker, do_return, retval_)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/operators/control_flow.py:1217, in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1215   _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1216 else:
# -> 1217   _py_if_stmt(cond, body, orelse)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/operators/control_flow.py:1270, in _py_if_stmt(cond, body, orelse)
#    1268 def _py_if_stmt(cond, body, orelse):
#    1269   """Overload of if_stmt that executes a Python if statement."""
# -> 1270   return body() if cond else orelse()
#
# File /tmp/__autograph_generated_filejhfkcdu9.py:29, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function.<locals>.if_body()
#      27 try:
#      28     do_return = True
# ---> 29     retval_ = ag__.converted_call(ag__.ld(func), tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      30 except:
#      31     do_return = False
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_file225s7pa5.py:28, in outer_factory.<locals>.inner_factory.<locals>.tf__minimize(self, loss_fn, var_list)
#      26 with ag__.FunctionScope('minimize', 'fscope', ag__.STD) as fscope:
#      27     parameters = [(ag__.ld(v)[0], ag__.ld(v)[1], ag__.if_exp(ag__.converted_call(ag__.ld(len), (ag__.ld(v),), None, fscope) > 2, lambda: ag__.ld(v)[2], lambda: None, 'ag__.converted_call(len, (v,), None, fscope) > 2')) for v in ag__.ld(var_list)]
# ---> 28     ag__.converted_call(ag__.ld(self)._natgrad_steps, (ag__.ld(loss_fn), ag__.ld(parameters)), None, fscope)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:441, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     439     result = converted_f(*effective_args, **kwargs)
#     440   else:
# --> 441     result = converted_f(*effective_args)
#     442 except Exception as e:
#     443   _attach_error_metadata(e, converted_f)
#
# File /tmp/__autograph_generated_filem09ei055.py:13, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_method(self, *args, **kwargs)
#      11 try:
#      12     do_return = True
# ---> 13     retval_ = ag__.converted_call(ag__.ld(wrapped_function), (ag__.ld(self),) + tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      14 except:
#      15     do_return = False
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_filejhfkcdu9.py:40, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function(*args, **kwargs)
#      38     nonlocal retval_, do_return
#      39     pass
# ---> 40 ag__.if_stmt(ag__.not_(ag__.converted_call(ag__.ld(get_enable_check_shapes), (), None, fscope)), if_body, else_body, get_state, set_state, ('do_return', 'retval_'), 2)
#      42 def get_state_8():
#      43     return (arg_map, ag__.ldu(lambda: arg_map[RESULT_TOKEN], 'arg_map[RESULT_TOKEN]'), checker, do_return, retval_)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/operators/control_flow.py:1217, in if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1215   _tf_if_stmt(cond, body, orelse, get_state, set_state, symbol_names, nouts)
#    1216 else:
# -> 1217   _py_if_stmt(cond, body, orelse)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/operators/control_flow.py:1270, in _py_if_stmt(cond, body, orelse)
#    1268 def _py_if_stmt(cond, body, orelse):
#    1269   """Overload of if_stmt that executes a Python if statement."""
# -> 1270   return body() if cond else orelse()
#
# File /tmp/__autograph_generated_filejhfkcdu9.py:29, in outer_factory.<locals>.inner_factory.<locals>.tf__wrapped_function.<locals>.if_body()
#      27 try:
#      28     do_return = True
# ---> 29     retval_ = ag__.converted_call(ag__.ld(func), tuple(ag__.ld(args)), dict(**ag__.ld(kwargs)), fscope)
#      30 except:
#      31     do_return = False
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:439, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     437 try:
#     438   if kwargs is not None:
# --> 439     result = converted_f(*effective_args, **kwargs)
#     440   else:
#     441     result = converted_f(*effective_args)
#
# File /tmp/__autograph_generated_filemk6jekj0.py:22, in outer_factory.<locals>.inner_factory.<locals>.tf___natgrad_steps(self, loss_fn, parameters)
#      20     ag__.converted_call(ag__.ld(tape).watch, (ag__.ld(q_mu_vars) + ag__.ld(q_sqrt_vars),), None, fscope)
#      21     loss = ag__.converted_call(ag__.ld(loss_fn), (), None, fscope)
# ---> 22 q_mu_grads, q_sqrt_grads = ag__.converted_call(ag__.ld(tape).gradient, (ag__.ld(loss), [ag__.ld(q_mu_vars), ag__.ld(q_sqrt_vars)]), None, fscope)
#      23 with ag__.ld(tf).name_scope(f'{ag__.ld(self).natgrad_name}/natural_gradient_steps'):
#      25     def get_state():
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:331, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     329 if conversion.is_in_allowlist_cache(f, options):
#     330   logging.log(2, 'Allowlisted %s: from cache', f)
# --> 331   return _call_unconverted(f, args, kwargs, options, False)
#     333 if ag_ctx.control_status_ctx().status == ag_ctx.Status.DISABLED:
#     334   logging.log(2, 'Allowlisted: %s: AutoGraph is disabled in context', f)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:460, in _call_unconverted(f, args, kwargs, options, update_cache)
#     458 if kwargs is not None:
#     459   return f(*args, **kwargs)
# --> 460 return f(*args)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/backprop.py:1066, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1060   output_gradients = (
#    1061       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1062           output_gradients))
#    1063   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1064                       for x in output_gradients]
# -> 1066 flat_grad = imperative_grad.imperative_grad(
#    1067     self._tape,
#    1068     flat_targets,
#    1069     flat_sources,
#    1070     output_gradients=output_gradients,
#    1071     sources_raw=flat_sources_raw,
#    1072     unconnected_gradients=unconnected_gradients)
#    1074 if not self._persistent:
#    1075   # Keep track of watched variables before setting tape to None
#    1076   self._watched_variables = self._tape.watched_variables()
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:311, in _DelayedRewriteGradientFunctions._backward.<locals>._backward_function(*args)
#     309 def _backward_function(*args):
#     310   call_op = outputs[0].op
# --> 311   return self._rewrite_forward_and_call_backward(call_op, *args)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:212, in _DelayedRewriteGradientFunctions._rewrite_forward_and_call_backward(self, op, *doutputs)
#     210 def _rewrite_forward_and_call_backward(self, op: ops.Operation, *doutputs):
#     211   """Add outputs to the forward call and feed them to the grad function."""
# --> 212   forward_function, backwards_function = self.forward_backward(len(doutputs))
#     213   if not backwards_function.outputs:
#     214     return backwards_function.structured_outputs
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:145, in _DelayedRewriteGradientFunctions.forward_backward(self, num_doutputs)
#     143 if forward_backward is not None:
#     144   return forward_backward
# --> 145 forward, backward = self._construct_forward_backward(num_doutputs)
#     146 self._cached_function_pairs[num_doutputs] = (forward, backward)
#     147 return forward, backward
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:188, in _DelayedRewriteGradientFunctions._construct_forward_backward(self, num_doutputs)
#     185 with self._func_graph.as_default():
#     186   backwards_graph = func_graph_module.FuncGraph(
#     187       _backward_name(self._func_graph.name))
# --> 188   func_graph_module.func_graph_from_py_func(
#     189       name=backwards_graph.name,
#     190       python_func=_backprop_function,
#     191       args=[], kwargs={},
#     192       signature=signature,
#     193       func_graph=backwards_graph)
#     194   backwards_graph_captures = backwards_graph.external_captures
#     195   captures_from_forward = [
#     196       c for c in backwards_graph_captures if
#     197       not isinstance(c, ops.EagerTensor) and c.graph is self._func_graph]
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/framework/func_graph.py:987, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#     984 else:
#     985   deps_control_manager = ops.NullContextmanager()
# --> 987 with func_graph.as_default(), deps_control_manager as deps_ctx:
#     988   current_scope = variable_scope.get_variable_scope()
#     989   default_use_resource = current_scope.use_resource
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/framework/auto_control_deps.py:459, in AutomaticControlDependencies.__exit__(self, unused_type, unused_value, unused_traceback)
#     456 resource_inputs = set()
#     457 # Check for any resource inputs. If we find any, we update control_inputs
#     458 # and last_write_to_resource.
# --> 459 for inp, resource_type in _get_resource_inputs(op):
#     460   is_read = resource_type == ResourceType.READ_ONLY
#     461   input_id = ops.tensor_id(inp)
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/framework/auto_control_deps.py:608, in _get_resource_inputs(op)
#     606 def _get_resource_inputs(op):
#     607   """Returns an iterable of resources touched by this `op`."""
# --> 608   reads, writes = utils.get_read_write_resource_inputs(op)
#     609   saturated = False
#     610   while not saturated:
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/framework/auto_control_deps_utils.py:108, in get_read_write_resource_inputs(op)
#     105   read_only_input_indices = op.get_attr(READ_ONLY_RESOURCE_INPUTS_ATTR)
#     106 except ValueError:
#     107   # Attr was not set. Add all resource inputs to `writes` and return.
# --> 108   writes.update(t for t in op.inputs if t.dtype == dtypes.resource)
#     109   return (reads, writes)
#     111 read_only_index = 0
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/util/object_identity.py:224, in ObjectIdentitySet.update(self, items)
#     223 def update(self, items):
# --> 224   self._storage.update([self._wrap_key(item) for item in items])
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/util/object_identity.py:224, in <listcomp>(.0)
#     223 def update(self, items):
# --> 224   self._storage.update([self._wrap_key(item) for item in items])
#
# File ~/micromamba/envs/gp/lib/python3.11/site-packages/tensorflow/python/framework/auto_control_deps_utils.py:108, in <genexpr>(.0)
#     105   read_only_input_indices = op.get_attr(READ_ONLY_RESOURCE_INPUTS_ATTR)
#     106 except ValueError:
#     107   # Attr was not set. Add all resource inputs to `writes` and return.
# --> 108   writes.update(t for t in op.inputs if t.dtype == dtypes.resource)
#     109   return (reads, writes)
#     111 read_only_index = 0
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(24, 3))
plt.plot(X, y)
for loc in segcpgp.LOCS:
    plt.axvline(loc, color="r")
    
with open("/home/janneke/changepoint-gp/TCPD/annotations.json") as f:
    annot = json.load(f)
print(annot["well_log"], sorted(segcpgp.LOCS))
# Out:
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} []

# %%
path = "/home/janneke/Downloads/cloudflare-radar_get-http-timeseries_20250508.json"    

with open(path) as f:
    data = json.load(f)
    
X = data["result"]["main"]["timestamps"]
y = data["result"]["main"]["values"]
plt.figure(figsize=(20, 4))
X = np.arange(len(y)).astype(float).reshape(-1, 1)
y = np.array(y).astype(float).reshape(-1, 1)
plt.plot(y)

segcpgp = SegCPGP()
segcpgp.fit(X, y, "spectral-5")
for loc in segcpgp.LOCS:
    plt.axvline(loc, color="r")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 13
#      10 y = np.array(y).astype(float).reshape(-1, 1)
#      11 plt.plot(y)
# ---> 13 segcpgp = SegCPGP()
#      14 segcpgp.fit(X, y, "spectral-5")
#      15 for loc in segcpgp.LOCS:
#
# NameError: name 'SegCPGP' is not defined

# %%
k = gpf.kernels.Constant(1)
X = np.arange(0, 100).reshape(-1, 1)
plt.imshow(k(X))

# %%
import kagglehub
import pandas as pd
# Download latest version
path = kagglehub.dataset_download("nikitamanaenkov/stock-portfolio-data-with-prices-and-indices")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.8), please consider upgrading to the latest version (0.3.12).
# Path to dataset files: /home/janneke/.cache/kagglehub/datasets/nikitamanaenkov/stock-portfolio-data-with-prices-and-indices/versions/1

# %%
df = pd.read_csv(path+"/Dow_Jones.csv")
print(df.columns)
y = df["Returns"].to_numpy().reshape(-1, 1)
X = np.arange(len(y)).reshape(-1, 1).astype(float)

plt.plot(X, y)
# Out:
# Index(['Date', 'Ticker', 'Open', 'High', 'Low', 'Close', 'Adjusted', 'Returns',
#        'Volume'],
#       dtype='object')

# %%
segcpgp = FastSegCPGP(n_ind=50)
dt = time.time()
segcpgp.fit(X, y, "noise")
print(time.time() - dt)
plot_result(X, y, segcpgp, ci)
# Out:
# 0.0 1311.0
# p nan df 3 location [1128.] steepness [1.]
# 5.168985605239868
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} []
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} []
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} []
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} []
# {'6': [179, 255, 281, 311, 343, 402, 413, 422, 432, 462, 464], '7': [179, 255, 281, 312, 343, 402, 412, 422, 432], '8': [179, 255, 282, 312, 343, 402, 413, 422, 432], '12': [177, 467], '13': [4, 179, 255, 281, 311, 344, 402, 412, 422, 432, 462, 464, 521, 526, 620, 643, 661]} []
